# %%
# !git clone https://github.com/nyuad-cai/CXR-ML-GZSL.git
# %cd CXR-ML-GZSL
# Out:
# Cloning into 'CXR-ML-GZSL'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 34 (delta 7), reused 30 (delta 7), pack-reused 2 (from 1)
# Receiving objects: 100% (34/34), 2.32 MiB | 7.78 MiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/CXR-ML-GZSL

# %%
# !pip install --upgrade pip
# !pip install \
  torch torchvision torchaudio \
  numpy \
  pandas \
  matplotlib \
  scikit-learn \
  opencv-python \
  tqdm \
  joblib \
  pillow \
  requests \
  networkx

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import tarfile

''' - used to extract the first time
# Path to your folder with .tar.gz files
folder_path = '/content/drive/MyDrive/Colab Notebooks/images'

# List all .tar.gz files
tar_files = [f for f in os.listdir(folder_path) if f.endswith('.tar.gz')]

# Extract each .tar.gz
for tar_file in tar_files:
    file_path = os.path.join(folder_path, tar_file)
    print(f'Extracting {file_path}...')
    with tarfile.open(file_path, 'r:gz') as tar:
        tar.extractall(path=folder_path)

print('All files extracted!')
'''

base_path = '/content/drive/MyDrive/Colab Notebooks/images'

#for root, dirs, files in os.walk(base_path):
#    print(root, len(files))
# Out:
# Mounted at /content/drive

# %%
# !python drive/MyDrive/Colab\ Notebooks/train.py \
  --vision-backbone densenet121 \
  --textual-embeddings /content/drive/MyDrive/Colab\ Notebooks/embeddings/nih_chest_xray_biobert.npy \
  --train-file /content/drive/MyDrive/Colab\ Notebooks/dataset_splits/train.txt \
  --val-file /content/drive/MyDrive/Colab\ Notebooks/dataset_splits/val.txt \
  --save-dir /content/drive/MyDrive/Colab\ Notebooks/checkpoints \
  --resume-from /content/drive/MyDrive/Colab\ Notebooks/checkpoints/last_epoch_checkpoint.pth.tar
# Out:
# [Errno 17] File exists: '/content/drive/MyDrive/Colab Notebooks/checkpoints'
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /usr/local/lib/python3.11/dist-packages/torch/nn/_reduction.py:51: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# ZSLNet(
#   (vision_backbone): DenseNet(
#     (features): Sequential(
#       (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# ...

# %%
# !python drive/MyDrive/Colab\ Notebooks/test.py \
  --vision-backbone densenet121 \
  --textual-embeddings /content/drive/MyDrive/Colab\ Notebooks/embeddings/nih_chest_xray_biobert.npy \
  --load-from /content/drive/MyDrive/Colab\ Notebooks/checkpoints/best_auroc_checkpoint.pth.tar
# Out:
# [Errno 17] File exists: 'checkpoints'
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /usr/local/lib/python3.11/dist-packages/torch/nn/_reduction.py:51: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# ZSLNet(
#   (vision_backbone): DenseNet(
#     (features): Sequential(
#       (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# ...
